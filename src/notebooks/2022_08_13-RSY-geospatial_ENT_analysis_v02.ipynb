# %% [markdown]
# Created a notebook so it can be organized. Started Aug 12, 2022

# %% [markdown]
# # Set up

# %%
#@title ## Base imports
import os
import sys
import numpy as np
import scipy
import sklearn
import sklearn.linear_model
import pandas as pd
import plotly.express as px

import warnings
import requests
import urllib.request
import json

# %%
#@title ## Option 1) Mount google drive and import my code

mountpoint_folder_name = "gdrive"  # can be anything, doesn't have to be "drive"
project_path_within_drive = "PythonProjects/GeospatialAnalysis/src" #@param {type:"string"}
project_path_full = os.path.join("/content/",mountpoint_folder_name,
                        "MyDrive",project_path_within_drive)
try:
    import google.colab.drive
    import os, sys
    # Need to move out of google drive directory if going to remount
    # %cd
    # drive.mount documentation can be accessed via: drive.mount?
    #Signature: drive.mount(mountpoint, force_remount=False, timeout_ms=120000, use_metadata_server=False)
    google.colab.drive.mount(os.path.join("/content/",mountpoint_folder_name), force_remount=True)  # mounts to a folder called mountpoint_folder_name

    if project_path_full not in sys.path:
        pass
        #sys.path.insert(0,project_path_full)
    # %cd {project_path_full}
    
except ModuleNotFoundError:  # in case not run in Google colab
    import traceback
    traceback.print_exc()
# Out:
# /root
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Computer Backups/Rahul Yerrabelli drive/PythonProjects/GeospatialAnalysis/src

# %%
#@title ## Option 2) Clone project files from GitHub

# !git clone https://github.com/ryerrabelli/GeospatialAnalysis.git

project_path_full = os.path.join("/content/","GeospatialAnalysis/src")
sys.path.insert(1,project_path_full)
# %cd GeospatialAnalysis
print(sys.path)
# Out:
# Cloning into 'GeospatialAnalysis'...
# remote: Enumerating objects: 198, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 198 (delta 0), reused 3 (delta 0), pack-reused 192
# Receiving objects: 100% (198/198), 31.41 MiB | 8.15 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# /content/GeospatialAnalysis
# ['', '/content/GeospatialAnalysis', '/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython']

# %% [markdown]
# # Helper functions

# %%
years = np.arange(2015,2019+1)

#@markdown # calc_regression()
def calc_regression(y, x):
    import collections
    regress = scipy.stats.linregress(x, y=y)
    # R = Pearson coefficient
    # p indicates p-value
    # Use ordered dict to retain order
    return collections.OrderedDict({
        "Mean": np.mean(y, axis=0),
        "Sum": np.sum(y, axis=0),
        "Slope": regress.slope, 
        "Intercept": regress.intercept, 
        "R": regress.rvalue, 
        "p": regress.pvalue, 
        })


"""
requests.get('http://172.28.0.2:9000/api/sessions').json() =
[{'id': 'e0a49454-e812-4d99-aa6f-9d7b80a9616c',
  'kernel': {'connections': 1,
   'execution_state': 'busy',
   'id': '6fd9c8b4-6573-4ffa-a7d6-f56803a0092c',
   'last_activity': '2021-12-01T08:12:08.239708Z',
   'name': 'python3'},
  'name': 'ModelInversions.ipynb',
  'notebook': {'name': 'ModelInversions.ipynb',
   'path': 'fileId=1ZAqQEIxR08eODSPEHvKPwbZoioVdV8L9'},
  'path': 'fileId=1ZAqQEIxR08eODSPEHvKPwbZoioVdV8L9',
  'type': 'notebook'}]
"""
notebook_filename = requests.get('http://172.28.0.2:9000/api/sessions').json()[0]['name']

#@markdown # get_path_to_save()
def get_path_to_save(file_prefix="", save_filename:str=None, save_in_subfolder:str=None, extension="png", create_folder_if_necessary=True):
    save_path = ["..","outputs",
                f"{notebook_filename.split('.',1)[0]}",  # use split to remove file extension
                ]
    if save_in_subfolder is not None:
        if isinstance(save_in_subfolder, (list, tuple, set, np.ndarray) ):
            save_path.append(**save_in_subfolder)
        else:  # should be a string then
            save_path.append(save_in_subfolder)
    save_path = os.path.join(*save_path)
    if not os.path.exists(save_path) and create_folder_if_necessary:
        os.makedirs(save_path)
    return os.path.join(save_path, file_prefix+save_filename+"."+extension)

#@markdown # save_df()
def save_df(df, file_name:str, ):
    df.to_excel( get_path_to_save(save_filename=file_name, extension="xlsx") )
    df.to_csv( get_path_to_save(save_filename=file_name, extension="csv") )

#@markdown # save_figure()
def save_figure(fig, file_name:str, animated=False):
    """
    fig is of type plotly.graph_objs._figure.Figure,
    Requires kaleido to be installed
    """
    fig.write_html( get_path_to_save(save_filename=file_name, extension="html") )
    if not animated:
        fig.write_image( get_path_to_save(save_filename=file_name, extension="svg"))
        fig.write_image( get_path_to_save(save_filename=file_name, extension="png") )
        fig.write_image( get_path_to_save(save_filename=file_name, extension="jpg") )

# %% [markdown]
# # Procedures analysis

# %% [markdown]
# ## Load ENT procedures df from csv file
# This is specifically a wide type df so it is one row per procedure with years as different columns.To understand what is meant by long type and wide type dataframes, see https://towardsdatascience.com/visualization-with-plotly-express-comprehensive-guide-eb5ee4b50b57

# %%
df_procedures_orig = pd.read_csv("data/2022_05_05 sums and slopes ent with HCPCS descriptions.csv", 
                           dtype={
                               "HCPCS Code": str,
                               "Total Number of Services": np.int64,
                               **{f"Total Number of Services: {year}": np.int64 for year in range(2015,2019+1)}
                               })  # gets per healthcare code info

# %% [markdown]
# The slope given in the csv file is actually the inverse slope. We need to either recalculate it or invert it. I will just recalculate all the regression values.

# %% [markdown]
# ## Clean df and recalculate regression

# %%
df_procedures_clean = df_procedures_orig.set_index(["HCPCS Code", "HCPCS Description"])

# Remove the "amount" word 
df_procedures_clean.columns = [col.replace("Total Medicare Payment Amount","Total Medicare Payment") for col in df_procedures_clean.columns]
# Drop columns besides the individual year ones. Will recalculate the other ones as a quality assurance check.
df_procedures_clean = df_procedures_clean.drop(columns=[col for col in df_procedures_clean.columns if ("slope" in col.lower() or "pearson" in col.lower() or ":" not in col)] )

# Rename the columns so they can be split  easier. The 20 is the first two digits of the year columns
df_procedures_clean.columns = [col.replace(": ",": : ").replace(": 20","Annual: 20") for col in df_procedures_clean.columns]

# Make Multiindex
df_procedures_clean.columns = pd.MultiIndex.from_tuples([tuple(col.split(": ")) if ":" in col else (col,"","") for col in df_procedures_clean.columns], names=["Category","Stat","Year"])
df_procedures_clean = df_procedures_clean[sorted(df_procedures_clean)]  # rearrange cols alphabetically


categories = df_procedures_clean.columns.levels[0]  #["Total Number of Services", "Total Medicare Payment Amount"]

# Calculate regression and sum and mean from individual year later
df_procedures_recalc = df_procedures_clean.copy()
for category in categories:
    new_df = df_procedures_recalc[(category,"Annual")].apply(calc_regression,axis=1, result_type="expand", args=(years,) )
    df_procedures_recalc[[(category,"Overall",new_col) for new_col in new_df.columns ]]=new_df
    #df_procedures_recalc[(category,"","Slope")]=df_procedures_recalc[(category,"Annual")].apply(calc_regression,axis=1)

# rearrange cols alphabetically, but only by the first two elements of the each column's name tuple
# This allows the order of the newly added columns to remain relative to themselves, but be rearranged relative to the other columns
df_procedures_recalc = df_procedures_recalc[sorted(df_procedures_recalc.columns, key=(lambda x: x[0:2]))]  

#df_procedures = df_procedures.sort_values(by=("Total Number of Services","","Sum"), ascending=False)  # sort rows by volume 
df_procedures_recalc = df_procedures_recalc.sort_values(by=("Total Medicare Payment","Overall","Mean"), ascending=False)  # sort rows by volume
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py:399: PerformanceWarning: indexing past lexsort depth may impact performance.
#   user_expressions, allow_stdin)

# %%
with pd.option_context('display.float_format', '{:,.2f}'.format):
    display(df_procedures_recalc)

save_df(df_procedures_recalc, "df_procedures_recalc")
# Out:
# Category                                                      Total Medicare Payment  \
# Stat                                                                          Annual
# Year                                                                            2015
# HCPCS Code HCPCS Description
# 14060      Tissue transfer repair of wound (10 sq centimet...           7,253,164.21
# 69930      Implantation of cochlear device                              4,164,557.97
# 31267      Removal of nasal sinus tissue using an endoscope             2,454,520.71
# 30520      Reshaping of nasal cartilage                                 3,822,391.75
# 30140      Removal of nasal air passage                                 4,090,571.97
# 15260      Relocation of patient skin to nose, ears, eyeli...           3,816,163.30
# 14301      Tissue transfer repair of wound (30.1 to 60.0 s...           3,422,400.08
# 14040      Tissue transfer repair of wound (10 sq centimet...           4,175,118.98
# 31575      Diagnostic examination of voice box using flexi...           4,095,655.56
# 31276      Exploration of nasal sinus using an endoscope                3,551,553.36
# 14041      Tissue transfer repair of wound (10.1 to 30.0 s...           2,481,173.43
# 60500      Removal or exploration of parathyroid glands                 1,466,292.92
# 31231      Diagnostic examination of nasal passages using ...           1,561,172.64
# 31579      Examination to assess movement of vocal cord fl...           1,329,457.32
# 69436      Incision of eardrum with insertion of eardrum t...           1,291,093.18
# 31256      Incision of nasal sinus using an endoscope                   1,021,363.93
# 31525      Diagnostic examination of voice box using an en...             548,628.32
# 11042      Removal of skin and tissue first 20 sq cm or less              509,299.24
# 31237      Biopsy or removal of nasal polyp or tissue usin...             689,656.89
# 30465      Widening of nasal passage                                      423,255.25
# 15004      Preparation of graft site of face, scalp, eyeli...             492,031.70
# 20926      Tissue graft                                                   426,939.03
# 21235      Obtaining ear cartilage for grafting                           268,245.90
# 31254      Partial removal of nasal sinus using an endoscope              278,635.35
# 31288      Removal of nasal sinus tissue using an endoscope               460,441.25
# 60240      Removal of thyroid                                             559,710.52
# 31571      Injection of vocal cords using an endoscope wit...             337,017.46
# 31541      Removal of growth of tongue and/or vocal cord s...             428,916.69
# 15120      Skin graft of face, scalp, eyelids, mouth, neck...             249,466.87
# 31253      Complete examination of nose and sinuses using ...                   0.00
# 31536      Biopsy of voice box using an endoscope with ope...             286,775.12
# 30930      Therapeutic fracture of nasal passages                         266,267.33
# 31259      Removal of tissue from sphenoid sinus using an ...                   0.00
# 11642      Removal of malignant growth (1.1 to 2.0 centime...             289,427.10
# 42415      Partial removal of salivary gland growth with r...             196,315.23
# 60220      Total removal of thyroid lobe on one side of th...             168,535.09
# 69631      Repair of eardrum and ear canal with opening to...             205,385.67
# 30130      Removal of nasal air passage                                   227,895.47
# 31257      Complete examination of nose and sinuses and re...                   0.00
# 31535      Biopsy of voice box using an endoscope                         181,200.03
# 31622      Diagnostic examination of lung airways using an...             185,955.57
# 15730      Creation of flap graft to midface                                    0.00
# 11643      Removal of malignant growth (2.1 to 3.0 centime...             139,924.42
# 69801      Incision of fluid canals of inner ear with infu...             149,143.78
# 69433      Incision of eardrum with insertion of eardrum t...             137,111.76
# 38510      Biopsy or removal of lymph nodes of neck, open ...             131,596.26
# 30802      Destruction of soft tissue in nasal passages                    93,891.34
# 43191      Diagnostic examination of esophagus using an en...              54,382.61
# 31238      Control of nasal bleeding using an endoscope                   103,707.75
# 43200      Diagnostic examination of esophagus using an en...              78,306.83
# 31240      Removal of nasal breathing passages using an en...              53,348.63
# 31526      Diagnostic examination of voice box using an en...              49,005.12
# 42826      Removal of tonsils patient age 12 or over                            0.00
#
# Category                                                                    \
# Stat
# Year                                                                  2016
# HCPCS Code HCPCS Description
# 14060      Tissue transfer repair of wound (10 sq centimet... 7,562,395.26
# 69930      Implantation of cochlear device                    4,694,007.58
# 31267      Removal of nasal sinus tissue using an endoscope   4,313,264.94
# 30520      Reshaping of nasal cartilage                       3,510,467.18
# 30140      Removal of nasal air passage                       4,163,402.15
# 15260      Relocation of patient skin to nose, ears, eyeli... 4,358,891.55
# 14301      Tissue transfer repair of wound (30.1 to 60.0 s... 3,325,471.33
# 14040      Tissue transfer repair of wound (10 sq centimet... 3,907,715.69
# 31575      Diagnostic examination of voice box using flexi... 3,367,114.38
# 31276      Exploration of nasal sinus using an endoscope      3,919,275.81
# 14041      Tissue transfer repair of wound (10.1 to 30.0 s... 2,174,377.77
# 60500      Removal or exploration of parathyroid glands       1,408,770.07
# 31231      Diagnostic examination of nasal passages using ... 1,473,524.08
# 31579      Examination to assess movement of vocal cord fl... 1,080,066.04
# 69436      Incision of eardrum with insertion of eardrum t... 1,541,750.79
# 31256      Incision of nasal sinus using an endoscope         1,035,079.99
# 31525      Diagnostic examination of voice box using an en...   783,501.65
# 11042      Removal of skin and tissue first 20 sq cm or less    600,263.11
# 31237      Biopsy or removal of nasal polyp or tissue usin...   700,877.99
# 30465      Widening of nasal passage                            460,478.90
# 15004      Preparation of graft site of face, scalp, eyeli...   549,173.13
# 20926      Tissue graft                                         450,643.34
# 21235      Obtaining ear cartilage for grafting                 348,416.66
# 31254      Partial removal of nasal sinus using an endoscope    433,153.49
# 31288      Removal of nasal sinus tissue using an endoscope     585,987.47
# 60240      Removal of thyroid                                   564,614.42
# 31571      Injection of vocal cords using an endoscope wit...   394,075.85
# 31541      Removal of growth of tongue and/or vocal cord s...   311,467.78
# 15120      Skin graft of face, scalp, eyelids, mouth, neck...   333,222.62
# 31253      Complete examination of nose and sinuses using ...         0.00
# 31536      Biopsy of voice box using an endoscope with ope...   252,209.73
# 30930      Therapeutic fracture of nasal passages               230,010.14
# 31259      Removal of tissue from sphenoid sinus using an ...         0.00
# 11642      Removal of malignant growth (1.1 to 2.0 centime...   245,483.24
# 42415      Partial removal of salivary gland growth with r...   287,774.38
# 60220      Total removal of thyroid lobe on one side of th...   208,492.40
# 69631      Repair of eardrum and ear canal with opening to...   220,079.14
# 30130      Removal of nasal air passage                         229,411.98
# 31257      Complete examination of nose and sinuses and re...         0.00
# 31535      Biopsy of voice box using an endoscope               232,824.57
# 31622      Diagnostic examination of lung airways using an...   191,174.40
# 15730      Creation of flap graft to midface                          0.00
# 11643      Removal of malignant growth (2.1 to 3.0 centime...   140,722.56
# 69801      Incision of fluid canals of inner ear with infu...   125,889.28
# 69433      Incision of eardrum with insertion of eardrum t...    95,794.52
# 38510      Biopsy or removal of lymph nodes of neck, open ...   124,915.20
# 30802      Destruction of soft tissue in nasal passages         144,814.17
# 43191      Diagnostic examination of esophagus using an en...    67,967.41
# 31238      Control of nasal bleeding using an endoscope          65,452.13
# 43200      Diagnostic examination of esophagus using an en...    75,608.99
# 31240      Removal of nasal breathing passages using an en...    27,758.99
# 31526      Diagnostic examination of voice box using an en...    34,247.57
# 42826      Removal of tonsils patient age 12 or over                  0.00
#
# Category                                                                    \
# Stat
# Year                                                                  2017
# HCPCS Code HCPCS Description
# 14060      Tissue transfer repair of wound (10 sq centimet... 6,718,042.68
# 69930      Implantation of cochlear device                    6,277,113.34
# 31267      Removal of nasal sinus tissue using an endoscope   4,546,272.86
# 30520      Reshaping of nasal cartilage                       3,887,689.27
# 30140      Removal of nasal air passage                       4,804,703.77
# 15260      Relocation of patient skin to nose, ears, eyeli... 3,827,316.88
# 14301      Tissue transfer repair of wound (30.1 to 60.0 s... 3,811,793.74
# 14040      Tissue transfer repair of wound (10 sq centimet... 3,725,634.72
# 31575      Diagnostic examination of voice box using flexi... 2,963,951.91
# 31276      Exploration of nasal sinus using an endoscope      4,510,942.92
# 14041      Tissue transfer repair of wound (10.1 to 30.0 s... 2,237,142.30
# 60500      Removal or exploration of parathyroid glands       1,410,847.34
# 31231      Diagnostic examination of nasal passages using ... 1,495,479.72
# 31579      Examination to assess movement of vocal cord fl...   957,141.66
# 69436      Incision of eardrum with insertion of eardrum t...   989,017.79
# 31256      Incision of nasal sinus using an endoscope         1,059,938.69
# 31525      Diagnostic examination of voice box using an en...   700,741.37
# 11042      Removal of skin and tissue first 20 sq cm or less  1,165,644.85
# 31237      Biopsy or removal of nasal polyp or tissue usin...   831,306.55
# 30465      Widening of nasal passage                            747,604.40
# 15004      Preparation of graft site of face, scalp, eyeli...   607,020.35
# 20926      Tissue graft                                         585,782.18
# 21235      Obtaining ear cartilage for grafting                 542,354.62
# 31254      Partial removal of nasal sinus using an endoscope    514,211.15
# 31288      Removal of nasal sinus tissue using an endoscope     820,141.39
# 60240      Removal of thyroid                                   289,389.15
# 31571      Injection of vocal cords using an endoscope wit...   319,825.53
# 31541      Removal of growth of tongue and/or vocal cord s...   318,524.17
# 15120      Skin graft of face, scalp, eyelids, mouth, neck...   322,363.94
# 31253      Complete examination of nose and sinuses using ...         0.00
# 31536      Biopsy of voice box using an endoscope with ope...   235,033.38
# 30930      Therapeutic fracture of nasal passages               285,853.59
# 31259      Removal of tissue from sphenoid sinus using an ...         0.00
# 11642      Removal of malignant growth (1.1 to 2.0 centime...   238,474.17
# 42415      Partial removal of salivary gland growth with r...   301,095.61
# 60220      Total removal of thyroid lobe on one side of th...   242,281.69
# 69631      Repair of eardrum and ear canal with opening to...   249,926.63
# 30130      Removal of nasal air passage                         216,179.41
# 31257      Complete examination of nose and sinuses and re...         0.00
# 31535      Biopsy of voice box using an endoscope               168,478.11
# 31622      Diagnostic examination of lung airways using an...   178,972.39
# 15730      Creation of flap graft to midface                          0.00
# 11643      Removal of malignant growth (2.1 to 3.0 centime...   128,258.93
# 69801      Incision of fluid canals of inner ear with infu...   101,842.11
# 69433      Incision of eardrum with insertion of eardrum t...   105,930.47
# 38510      Biopsy or removal of lymph nodes of neck, open ...   113,084.72
# 30802      Destruction of soft tissue in nasal passages          68,066.24
# 43191      Diagnostic examination of esophagus using an en...    68,026.51
# 31238      Control of nasal bleeding using an endoscope          57,244.23
# 43200      Diagnostic examination of esophagus using an en...    63,212.10
# 31240      Removal of nasal breathing passages using an en...    47,718.67
# 31526      Diagnostic examination of voice box using an en...    47,429.81
# 42826      Removal of tonsils patient age 12 or over              6,851.10
#
# Category                                                                    \
# Stat
# Year                                                                  2018
# HCPCS Code HCPCS Description
# 14060      Tissue transfer repair of wound (10 sq centimet... 7,190,368.43
# 69930      Implantation of cochlear device                    8,438,188.15
# 31267      Removal of nasal sinus tissue using an endoscope   5,081,500.91
# 30520      Reshaping of nasal cartilage                       4,454,847.45
# 30140      Removal of nasal air passage                       3,414,962.46
# 15260      Relocation of patient skin to nose, ears, eyeli... 3,987,570.86
# 14301      Tissue transfer repair of wound (30.1 to 60.0 s... 4,247,217.10
# 14040      Tissue transfer repair of wound (10 sq centimet... 3,471,107.63
# 31575      Diagnostic examination of voice box using flexi... 3,007,322.23
# 31276      Exploration of nasal sinus using an endoscope      1,568,753.14
# 14041      Tissue transfer repair of wound (10.1 to 30.0 s... 2,455,397.22
# 60500      Removal or exploration of parathyroid glands       1,862,490.74
# 31231      Diagnostic examination of nasal passages using ... 1,726,503.13
# 31579      Examination to assess movement of vocal cord fl... 1,213,382.40
# 69436      Incision of eardrum with insertion of eardrum t... 1,045,676.06
# 31256      Incision of nasal sinus using an endoscope           913,926.80
# 31525      Diagnostic examination of voice box using an en... 1,022,976.64
# 11042      Removal of skin and tissue first 20 sq cm or less  1,317,431.90
# 31237      Biopsy or removal of nasal polyp or tissue usin...   817,973.23
# 30465      Widening of nasal passage                            606,739.83
# 15004      Preparation of graft site of face, scalp, eyeli...   614,663.70
# 20926      Tissue graft                                         610,737.46
# 21235      Obtaining ear cartilage for grafting                 589,131.20
# 31254      Partial removal of nasal sinus using an endoscope    551,675.73
# 31288      Removal of nasal sinus tissue using an endoscope     132,215.78
# 60240      Removal of thyroid                                   325,602.27
# 31571      Injection of vocal cords using an endoscope wit...   402,641.13
# 31541      Removal of growth of tongue and/or vocal cord s...   364,008.38
# 15120      Skin graft of face, scalp, eyelids, mouth, neck...   447,454.72
# 31253      Complete examination of nose and sinuses using ...   831,021.41
# 31536      Biopsy of voice box using an endoscope with ope...   268,100.83
# 30930      Therapeutic fracture of nasal passages               267,984.22
# 31259      Removal of tissue from sphenoid sinus using an ...   560,920.86
# 11642      Removal of malignant growth (1.1 to 2.0 centime...   213,254.24
# 42415      Partial removal of salivary gland growth with r...   183,520.11
# 60220      Total removal of thyroid lobe on one side of th...   258,011.07
# 69631      Repair of eardrum and ear canal with opening to...   192,457.49
# 30130      Removal of nasal air passage                         165,502.70
# 31257      Complete examination of nose and sinuses and re...   439,556.46
# 31535      Biopsy of voice box using an endoscope               175,099.42
# 31622      Diagnostic examination of lung airways using an...   174,191.34
# 15730      Creation of flap graft to midface                    309,666.39
# 11643      Removal of malignant growth (2.1 to 3.0 centime...   129,997.44
# 69801      Incision of fluid canals of inner ear with infu...   117,694.22
# 69433      Incision of eardrum with insertion of eardrum t...   119,417.25
# 38510      Biopsy or removal of lymph nodes of neck, open ...    74,247.77
# 30802      Destruction of soft tissue in nasal passages          98,175.24
# 43191      Diagnostic examination of esophagus using an en...    81,217.55
# 31238      Control of nasal bleeding using an endoscope          70,939.82
# 43200      Diagnostic examination of esophagus using an en...    63,046.87
# 31240      Removal of nasal breathing passages using an en...    62,021.47
# 31526      Diagnostic examination of voice box using an en...    44,119.52
# 42826      Removal of tonsils patient age 12 or over                  0.00
#
# Category                                                                    \
# Stat
# Year                                                                  2019
# HCPCS Code HCPCS Description
# 14060      Tissue transfer repair of wound (10 sq centimet... 6,664,704.64
# 69930      Implantation of cochlear device                    9,406,753.83
# 31267      Removal of nasal sinus tissue using an endoscope   5,474,723.78
# 30520      Reshaping of nasal cartilage                       4,932,682.76
# 30140      Removal of nasal air passage                       3,699,636.24
# 15260      Relocation of patient skin to nose, ears, eyeli... 3,502,561.56
# 14301      Tissue transfer repair of wound (30.1 to 60.0 s... 4,435,581.13
# 14040      Tissue transfer repair of wound (10 sq centimet... 3,582,572.68
# 31575      Diagnostic examination of voice box using flexi... 3,164,731.95
# 31276      Exploration of nasal sinus using an endoscope      1,926,164.94
# 14041      Tissue transfer repair of wound (10.1 to 30.0 s... 2,448,822.04
# 60500      Removal or exploration of parathyroid glands       2,197,618.10
# 31231      Diagnostic examination of nasal passages using ... 1,865,779.80
# 31579      Examination to assess movement of vocal cord fl... 1,418,448.74
# 69436      Incision of eardrum with insertion of eardrum t... 1,013,430.98
# 31256      Incision of nasal sinus using an endoscope           991,835.22
# 31525      Diagnostic examination of voice box using an en... 1,268,959.66
# 11042      Removal of skin and tissue first 20 sq cm or less    644,733.10
# 31237      Biopsy or removal of nasal polyp or tissue usin...   945,048.46
# 30465      Widening of nasal passage                            738,921.41
# 15004      Preparation of graft site of face, scalp, eyeli...   645,711.34
# 20926      Tissue graft                                         556,106.03
# 21235      Obtaining ear cartilage for grafting                 547,903.08
# 31254      Partial removal of nasal sinus using an endoscope    492,158.95
# 31288      Removal of nasal sinus tissue using an endoscope     167,881.55
# 60240      Removal of thyroid                                   324,832.89
# 31571      Injection of vocal cords using an endoscope wit...   329,493.71
# 31541      Removal of growth of tongue and/or vocal cord s...   343,437.09
# 15120      Skin graft of face, scalp, eyelids, mouth, neck...   374,959.52
# 31253      Complete examination of nose and sinuses using ...   880,259.72
# 31536      Biopsy of voice box using an endoscope with ope...   278,485.73
# 30930      Therapeutic fracture of nasal passages               269,112.82
# 31259      Removal of tissue from sphenoid sinus using an ...   751,217.13
# 11642      Removal of malignant growth (1.1 to 2.0 centime...   214,496.56
# 42415      Partial removal of salivary gland growth with r...   183,033.56
# 60220      Total removal of thyroid lobe on one side of th...   259,174.37
# 69631      Repair of eardrum and ear canal with opening to...   258,975.60
# 30130      Removal of nasal air passage                         186,750.20
# 31257      Complete examination of nose and sinuses and re...   545,807.53
# 31535      Biopsy of voice box using an endoscope               178,249.54
# 31622      Diagnostic examination of lung airways using an...   169,167.54
# 15730      Creation of flap graft to midface                    462,171.85
# 11643      Removal of malignant growth (2.1 to 3.0 centime...   103,648.28
# 69801      Incision of fluid canals of inner ear with infu...    99,843.45
# 69433      Incision of eardrum with insertion of eardrum t...   120,424.96
# 38510      Biopsy or removal of lymph nodes of neck, open ...   112,143.68
# 30802      Destruction of soft tissue in nasal passages         115,199.38
# 43191      Diagnostic examination of esophagus using an en...    93,565.24
# 31238      Control of nasal bleeding using an endoscope          58,204.32
# 43200      Diagnostic examination of esophagus using an en...    46,478.67
# 31240      Removal of nasal breathing passages using an en...    81,228.96
# 31526      Diagnostic examination of voice box using an en...    29,723.89
# 42826      Removal of tonsils patient age 12 or over                  0.00
#
# Category                                                                    \
# Stat                                                               Overall
# Year                                                                  Mean
# HCPCS Code HCPCS Description
# 14060      Tissue transfer repair of wound (10 sq centimet... 7,077,735.04
# 69930      Implantation of cochlear device                    6,596,124.17
# 31267      Removal of nasal sinus tissue using an endoscope   4,374,056.64
# 30520      Reshaping of nasal cartilage                       4,121,615.68
# 30140      Removal of nasal air passage                       4,034,655.32
# 15260      Relocation of patient skin to nose, ears, eyeli... 3,898,500.83
# 14301      Tissue transfer repair of wound (30.1 to 60.0 s... 3,848,492.68
# 14040      Tissue transfer repair of wound (10 sq centimet... 3,772,429.94
# 31575      Diagnostic examination of voice box using flexi... 3,319,755.21
# 31276      Exploration of nasal sinus using an endoscope      3,095,338.03
# 14041      Tissue transfer repair of wound (10.1 to 30.0 s... 2,359,382.55
# 60500      Removal or exploration of parathyroid glands       1,669,203.83
# 31231      Diagnostic examination of nasal passages using ... 1,624,491.87
# 31579      Examination to assess movement of vocal cord fl... 1,199,699.23
# 69436      Incision of eardrum with insertion of eardrum t... 1,176,193.76
# 31256      Incision of nasal sinus using an endoscope         1,004,428.93
# 31525      Diagnostic examination of voice box using an en...   864,961.53
# 11042      Removal of skin and tissue first 20 sq cm or less    847,474.44
# 31237      Biopsy or removal of nasal polyp or tissue usin...   796,972.62
# 30465      Widening of nasal passage                            595,399.96
# 15004      Preparation of graft site of face, scalp, eyeli...   581,720.04
# 20926      Tissue graft                                         526,041.61
# 21235      Obtaining ear cartilage for grafting                 459,210.29
# 31254      Partial removal of nasal sinus using an endoscope    453,966.93
# 31288      Removal of nasal sinus tissue using an endoscope     433,333.49
# 60240      Removal of thyroid                                   412,829.85
# 31571      Injection of vocal cords using an endoscope wit...   356,610.74
# 31541      Removal of growth of tongue and/or vocal cord s...   353,270.82
# 15120      Skin graft of face, scalp, eyelids, mouth, neck...   345,493.53
# 31253      Complete examination of nose and sinuses using ...   342,256.23
# 31536      Biopsy of voice box using an endoscope with ope...   264,120.96
# 30930      Therapeutic fracture of nasal passages               263,845.62
# 31259      Removal of tissue from sphenoid sinus using an ...   262,427.60
# 11642      Removal of malignant growth (1.1 to 2.0 centime...   240,227.06
# 42415      Partial removal of salivary gland growth with r...   230,347.78
# 60220      Total removal of thyroid lobe on one side of th...   227,298.92
# 69631      Repair of eardrum and ear canal with opening to...   225,364.91
# 30130      Removal of nasal air passage                         205,147.95
# 31257      Complete examination of nose and sinuses and re...   197,072.80
# 31535      Biopsy of voice box using an endoscope               187,170.33
# 31622      Diagnostic examination of lung airways using an...   179,892.25
# 15730      Creation of flap graft to midface                    154,367.65
# 11643      Removal of malignant growth (2.1 to 3.0 centime...   128,510.33
# 69801      Incision of fluid canals of inner ear with infu...   118,882.57
# 69433      Incision of eardrum with insertion of eardrum t...   115,735.79
# 38510      Biopsy or removal of lymph nodes of neck, open ...   111,197.53
# 30802      Destruction of soft tissue in nasal passages         104,029.27
# 43191      Diagnostic examination of esophagus using an en...    73,031.86
# 31238      Control of nasal bleeding using an endoscope          71,109.65
# 43200      Diagnostic examination of esophagus using an en...    65,330.69
# 31240      Removal of nasal breathing passages using an en...    54,415.34
# 31526      Diagnostic examination of voice box using an en...    40,905.18
# 42826      Removal of tonsils patient age 12 or over              1,370.22
#
# Category                                                                     \
# Stat
# Year                                                                    Sum
# HCPCS Code HCPCS Description
# 14060      Tissue transfer repair of wound (10 sq centimet... 35,388,675.22
# 69930      Implantation of cochlear device                    32,980,620.87
# 31267      Removal of nasal sinus tissue using an endoscope   21,870,283.20
# 30520      Reshaping of nasal cartilage                       20,608,078.41
# 30140      Removal of nasal air passage                       20,173,276.59
# 15260      Relocation of patient skin to nose, ears, eyeli... 19,492,504.15
# 14301      Tissue transfer repair of wound (30.1 to 60.0 s... 19,242,463.38
# 14040      Tissue transfer repair of wound (10 sq centimet... 18,862,149.70
# 31575      Diagnostic examination of voice box using flexi... 16,598,776.03
# 31276      Exploration of nasal sinus using an endoscope      15,476,690.17
# 14041      Tissue transfer repair of wound (10.1 to 30.0 s... 11,796,912.76
# 60500      Removal or exploration of parathyroid glands        8,346,019.17
# 31231      Diagnostic examination of nasal passages using ...  8,122,459.37
# 31579      Examination to assess movement of vocal cord fl...  5,998,496.16
# 69436      Incision of eardrum with insertion of eardrum t...  5,880,968.80
# 31256      Incision of nasal sinus using an endoscope          5,022,144.63
# 31525      Diagnostic examination of voice box using an en...  4,324,807.64
# 11042      Removal of skin and tissue first 20 sq cm or less   4,237,372.20
# 31237      Biopsy or removal of nasal polyp or tissue usin...  3,984,863.12
# 30465      Widening of nasal passage                           2,976,999.79
# 15004      Preparation of graft site of face, scalp, eyeli...  2,908,600.22
# 20926      Tissue graft                                        2,630,208.04
# 21235      Obtaining ear cartilage for grafting                2,296,051.46
# 31254      Partial removal of nasal sinus using an endoscope   2,269,834.67
# 31288      Removal of nasal sinus tissue using an endoscope    2,166,667.44
# 60240      Removal of thyroid                                  2,064,149.25
# 31571      Injection of vocal cords using an endoscope wit...  1,783,053.68
# 31541      Removal of growth of tongue and/or vocal cord s...  1,766,354.11
# 15120      Skin graft of face, scalp, eyelids, mouth, neck...  1,727,467.67
# 31253      Complete examination of nose and sinuses using ...  1,711,281.13
# 31536      Biopsy of voice box using an endoscope with ope...  1,320,604.79
# 30930      Therapeutic fracture of nasal passages              1,319,228.10
# 31259      Removal of tissue from sphenoid sinus using an ...  1,312,137.99
# 11642      Removal of malignant growth (1.1 to 2.0 centime...  1,201,135.31
# 42415      Partial removal of salivary gland growth with r...  1,151,738.89
# 60220      Total removal of thyroid lobe on one side of th...  1,136,494.62
# 69631      Repair of eardrum and ear canal with opening to...  1,126,824.53
# 30130      Removal of nasal air passage                        1,025,739.76
# 31257      Complete examination of nose and sinuses and re...    985,363.99
# 31535      Biopsy of voice box using an endoscope                935,851.67
# 31622      Diagnostic examination of lung airways using an...    899,461.24
# 15730      Creation of flap graft to midface                     771,838.24
# 11643      Removal of malignant growth (2.1 to 3.0 centime...    642,551.63
# 69801      Incision of fluid canals of inner ear with infu...    594,412.84
# 69433      Incision of eardrum with insertion of eardrum t...    578,678.96
# 38510      Biopsy or removal of lymph nodes of neck, open ...    555,987.63
# 30802      Destruction of soft tissue in nasal passages          520,146.37
# 43191      Diagnostic examination of esophagus using an en...    365,159.32
# 31238      Control of nasal bleeding using an endoscope          355,548.25
# 43200      Diagnostic examination of esophagus using an en...    326,653.46
# 31240      Removal of nasal breathing passages using an en...    272,076.72
# 31526      Diagnostic examination of voice box using an en...    204,525.91
# 42826      Removal of tonsils patient age 12 or over               6,851.10
#
# Category                                                                    \
# Stat
# Year                                                                 Slope
# HCPCS Code HCPCS Description
# 14060      Tissue transfer repair of wound (10 sq centimet...  -154,894.60
# 69930      Implantation of cochlear device                    1,422,857.23
# 31267      Removal of nasal sinus tissue using an endoscope     680,864.21
# 30520      Reshaping of nasal cartilage                         316,496.23
# 30140      Removal of nasal air passage                        -153,031.11
# 15260      Relocation of patient skin to nose, ears, eyeli...   -99,852.42
# 14301      Tissue transfer repair of wound (30.1 to 60.0 s...   294,810.79
# 14040      Tissue transfer repair of wound (10 sq centimet...  -162,170.07
# 31575      Diagnostic examination of voice box using flexi...  -222,163.94
# 31276      Exploration of nasal sinus using an endoscope       -560,129.95
# 14041      Tissue transfer repair of wound (10.1 to 30.0 s...    21,631.67
# 60500      Removal or exploration of parathyroid glands         191,637.10
# 31231      Diagnostic examination of nasal passages using ...    86,219.34
# 31579      Examination to assess movement of vocal cord fl...    31,129.92
# 69436      Incision of eardrum with insertion of eardrum t...  -105,139.91
# 31256      Incision of nasal sinus using an endoscope           -18,021.06
# 31525      Diagnostic examination of voice box using an en...   168,013.77
# 11042      Removal of skin and tissue first 20 sq cm or less     98,803.65
# 31237      Biopsy or removal of nasal polyp or tissue usin...    62,787.84
# 30465      Widening of nasal passage                             77,759.32
# 15004      Preparation of graft site of face, scalp, eyeli...    37,284.98
# 20926      Tissue graft                                          41,842.81
# 21235      Obtaining ear cartilage for grafting                  80,002.89
# 31254      Partial removal of nasal sinus using an endoscope     54,556.94
# 31288      Removal of nasal sinus tissue using an endoscope    -103,889.11
# 60240      Removal of thyroid                                   -70,876.74
# 31571      Injection of vocal cords using an endoscope wit...      -648.22
# 31541      Removal of growth of tongue and/or vocal cord s...   -11,841.86
# 15120      Skin graft of face, scalp, eyelids, mouth, neck...    36,521.74
# 31253      Complete examination of nose and sinuses using ...   259,154.08
# 31536      Biopsy of voice box using an endoscope with ope...       -68.77
# 30930      Therapeutic fracture of nasal passages                 4,366.51
# 31259      Removal of tissue from sphenoid sinus using an ...   206,335.51
# 11642      Removal of malignant growth (1.1 to 2.0 centime...   -18,209.01
# 42415      Partial removal of salivary gland growth with r...   -13,081.76
# 60220      Total removal of thyroid lobe on one side of th...    23,079.72
# 69631      Repair of eardrum and ear canal with opening to...     7,955.82
# 30130      Removal of nasal air passage                         -14,619.98
# 31257      Complete examination of nose and sinuses and re...   153,117.15
# 31535      Biopsy of voice box using an endoscope                -6,362.61
# 31622      Diagnostic examination of lung airways using an...    -5,055.91
# 15730      Creation of flap graft to midface                    123,401.01
# 11643      Removal of malignant growth (2.1 to 3.0 centime...    -8,327.74
# 69801      Incision of fluid canals of inner ear with infu...   -10,679.57
# 69433      Incision of eardrum with insertion of eardrum t...      -975.09
# 38510      Biopsy or removal of lymph nodes of neck, open ...    -8,957.26
# 30802      Destruction of soft tissue in nasal passages            -402.28
# 43191      Diagnostic examination of esophagus using an en...     9,161.54
# 31238      Control of nasal bleeding using an endoscope          -8,551.92
# 43200      Diagnostic examination of esophagus using an en...    -7,621.84
# 31240      Removal of nasal breathing passages using an en...     9,002.31
# 31526      Diagnostic examination of voice box using an en...    -2,869.05
# 42826      Removal of tonsils patient age 12 or over                 -0.00
#
# Category                                                                         \
# Stat
# Year                                                                  Intercept
# HCPCS Code HCPCS Description
# 14060      Tissue transfer repair of wound (10 sq centimet...    319,500,137.19
# 69930      Implantation of cochlear device                    -2,863,306,906.72
# 31267      Removal of nasal sinus tissue using an endoscope   -1,368,929,056.95
# 30520      Reshaping of nasal cartilage                         -634,251,278.21
# 30140      Removal of nasal air passage                          312,698,414.27
# 15260      Relocation of patient skin to nose, ears, eyeli...    205,300,825.92
# 14301      Tissue transfer repair of wound (30.1 to 60.0 s...   -590,784,864.70
# 14040      Tissue transfer repair of wound (10 sq centimet...    330,869,453.06
# 31575      Diagnostic examination of voice box using flexi...    451,424,416.13
# 31276      Exploration of nasal sinus using an endoscope       1,132,877,449.20
# 14041      Tissue transfer repair of wound (10.1 to 30.0 s...    -41,271,689.79
# 60500      Removal or exploration of parathyroid glands         -384,862,832.92
# 31231      Diagnostic examination of nasal passages using ...   -172,279,910.86
# 31579      Examination to assess movement of vocal cord fl...    -61,589,349.41
# 69436      Incision of eardrum with insertion of eardrum t...    213,243,398.28
# 31256      Incision of nasal sinus using an endoscope             37,352,908.96
# 31525      Diagnostic examination of voice box using an en...   -338,018,806.51
# 11042      Removal of skin and tissue first 20 sq cm or less    -198,439,489.63
# 31237      Biopsy or removal of nasal polyp or tissue usin...   -125,846,096.62
# 30465      Widening of nasal passage                            -156,245,158.57
# 15004      Preparation of graft site of face, scalp, eyeli...    -74,622,094.70
# 20926      Tissue graft                                          -83,870,910.20
# 21235      Obtaining ear cartilage for grafting                 -160,906,618.84
# 31254      Partial removal of nasal sinus using an endoscope    -109,587,389.11
# 31288      Removal of nasal sinus tissue using an endoscope      209,977,666.34
# 60240      Removal of thyroid                                    143,371,216.45
# 31571      Injection of vocal cords using an endoscope wit...      1,664,074.51
# 31541      Removal of growth of tongue and/or vocal cord s...     24,238,302.44
# 15120      Skin graft of face, scalp, eyelids, mouth, neck...    -73,318,856.05
# 31253      Complete examination of nose and sinuses using ...   -522,371,533.22
# 31536      Biopsy of voice box using an endoscope with ope...        402,826.01
# 30930      Therapeutic fracture of nasal passages                 -8,543,396.98
# 31259      Removal of tissue from sphenoid sinus using an ...   -415,916,300.11
# 11642      Removal of malignant growth (1.1 to 2.0 centime...     36,967,796.20
# 42415      Partial removal of salivary gland growth with r...     26,616,259.72
# 60220      Total removal of thyroid lobe on one side of th...    -46,324,502.37
# 69631      Repair of eardrum and ear canal with opening to...    -15,821,526.05
# 30130      Removal of nasal air passage                           29,693,651.65
# 31257      Complete examination of nose and sinuses and re...   -308,640,222.79
# 31535      Biopsy of voice box using an endoscope                 13,020,560.75
# 31622      Diagnostic examination of lung airways using an...     10,377,666.75
# 15730      Creation of flap graft to midface                    -248,745,467.50
# 11643      Removal of malignant growth (2.1 to 3.0 centime...     16,925,561.91
# 69801      Incision of fluid canals of inner ear with infu...     21,659,579.29
# 69433      Incision of eardrum with insertion of eardrum t...      2,082,486.27
# 38510      Biopsy or removal of lymph nodes of neck, open ...     18,177,988.93
# 30802      Destruction of soft tissue in nasal passages              915,438.12
# 43191      Diagnostic examination of esophagus using an en...    -18,405,794.32
# 31238      Control of nasal bleeding using an endoscope           17,320,326.24
# 43200      Diagnostic examination of esophagus using an en...     15,438,590.04
# 31240      Removal of nasal breathing passages using an en...    -18,103,251.99
# 31526      Diagnostic examination of voice box using an en...      5,827,781.05
# 42826      Removal of tonsils patient age 12 or over                   1,370.22
#
# Category                                                             ...  \
# Stat                                                                 ...
# Year                                                              R  ...
# HCPCS Code HCPCS Description                                         ...
# 14060      Tissue transfer repair of wound (10 sq centimet... -0.64  ...
# 69930      Implantation of cochlear device                     0.98  ...
# 31267      Removal of nasal sinus tissue using an endoscope    0.92  ...
# 30520      Reshaping of nasal cartilage                        0.88  ...
# 30140      Removal of nasal air passage                       -0.46  ...
# 15260      Relocation of patient skin to nose, ears, eyeli... -0.51  ...
# 14301      Tissue transfer repair of wound (30.1 to 60.0 s...  0.95  ...
# 14040      Tissue transfer repair of wound (10 sq centimet... -0.92  ...
# 31575      Diagnostic examination of voice box using flexi... -0.76  ...
# 31276      Exploration of nasal sinus using an endoscope      -0.69  ...
# 14041      Tissue transfer repair of wound (10.1 to 30.0 s...  0.24  ...
# 60500      Removal or exploration of parathyroid glands        0.86  ...
# 31231      Diagnostic examination of nasal passages using ...  0.81  ...
# 31579      Examination to assess movement of vocal cord fl...  0.26  ...
# 69436      Incision of eardrum with insertion of eardrum t... -0.70  ...
# 31256      Incision of nasal sinus using an endoscope         -0.51  ...
# 31525      Diagnostic examination of voice box using an en...  0.94  ...
# 11042      Removal of skin and tissue first 20 sq cm or less   0.43  ...
# 31237      Biopsy or removal of nasal polyp or tissue usin...  0.94  ...
# 30465      Widening of nasal passage                           0.81  ...
# 15004      Preparation of graft site of face, scalp, eyeli...  0.97  ...
# 20926      Tissue graft                                        0.80  ...
# 21235      Obtaining ear cartilage for grafting                0.89  ...
# 31254      Partial removal of nasal sinus using an endoscope   0.81  ...
# 31288      Removal of nasal sinus tissue using an endoscope   -0.57  ...
# 60240      Removal of thyroid                                 -0.82  ...
# 31571      Injection of vocal cords using an endoscope wit... -0.03  ...
# 31541      Removal of growth of tongue and/or vocal cord s... -0.40  ...
# 15120      Skin graft of face, scalp, eyelids, mouth, neck...  0.79  ...
# 31253      Complete examination of nose and sinuses using ...  0.87  ...
# 31536      Biopsy of voice box using an endoscope with ope... -0.01  ...
# 30930      Therapeutic fracture of nasal passages              0.34  ...
# 31259      Removal of tissue from sphenoid sinus using an ...  0.89  ...
# 11642      Removal of malignant growth (1.1 to 2.0 centime... -0.93  ...
# 42415      Partial removal of salivary gland growth with r... -0.35  ...
# 60220      Total removal of thyroid lobe on one side of th...  0.94  ...
# 69631      Repair of eardrum and ear canal with opening to...  0.44  ...
# 30130      Removal of nasal air passage                       -0.83  ...
# 31257      Complete examination of nose and sinuses and re...  0.89  ...
# 31535      Biopsy of voice box using an endoscope             -0.39  ...
# 31622      Diagnostic examination of lung airways using an... -0.90  ...
# 15730      Creation of flap graft to midface                   0.89  ...
# 11643      Removal of malignant growth (2.1 to 3.0 centime... -0.88  ...
# 69801      Incision of fluid canals of inner ear with infu... -0.84  ...
# 69433      Incision of eardrum with insertion of eardrum t... -0.10  ...
# 38510      Biopsy or removal of lymph nodes of neck, open ... -0.64  ...
# 30802      Destruction of soft tissue in nasal passages       -0.02  ...
# 43191      Diagnostic examination of esophagus using an en...  0.97  ...
# 31238      Control of nasal bleeding using an endoscope       -0.71  ...
# 43200      Diagnostic examination of esophagus using an en... -0.95  ...
# 31240      Removal of nasal breathing passages using an en...  0.73  ...
# 31526      Diagnostic examination of voice box using an en... -0.53  ...
# 42826      Removal of tonsils patient age 12 or over          -0.00  ...
#
# Category                                                      Total Number of Services  \
# Stat                                                                            Annual
# Year                                                                              2016
# HCPCS Code HCPCS Description
# 14060      Tissue transfer repair of wound (10 sq centimet...                    14043
# 69930      Implantation of cochlear device                                        1818
# 31267      Removal of nasal sinus tissue using an endoscope                       8394
# 30520      Reshaping of nasal cartilage                                           9508
# 30140      Removal of nasal air passage                                          11063
# 15260      Relocation of patient skin to nose, ears, eyeli...                     7518
# 14301      Tissue transfer repair of wound (30.1 to 60.0 s...                     4516
# 14040      Tissue transfer repair of wound (10 sq centimet...                     7635
# 31575      Diagnostic examination of voice box using flexi...                    58104
# 31276      Exploration of nasal sinus using an endoscope                          6240
# 14041      Tissue transfer repair of wound (10.1 to 30.0 s...                     3871
# 60500      Removal or exploration of parathyroid glands                           1870
# 31231      Diagnostic examination of nasal passages using ...                    32245
# 31579      Examination to assess movement of vocal cord fl...                     9957
# 69436      Incision of eardrum with insertion of eardrum t...                     4125
# 31256      Incision of nasal sinus using an endoscope                             3847
# 31525      Diagnostic examination of voice box using an en...                     5918
# 11042      Removal of skin and tissue first 20 sq cm or less                      8266
# 31237      Biopsy or removal of nasal polyp or tissue usin...                     3961
# 30465      Widening of nasal passage                                               514
# 15004      Preparation of graft site of face, scalp, eyeli...                     3988
# 20926      Tissue graft                                                            865
# 21235      Obtaining ear cartilage for grafting                                   1155
# 31254      Partial removal of nasal sinus using an endoscope                       890
# 31288      Removal of nasal sinus tissue using an endoscope                       1421
# 60240      Removal of thyroid                                                      793
# ...
# 31256      Incision of nasal sinus using an endoscope          18,109.00
# 31525      Diagnostic examination of voice box using an en...  32,640.00
# 11042      Removal of skin and tissue first 20 sq cm or less   46,073.00
# 31237      Biopsy or removal of nasal polyp or tissue usin...  22,980.00
# 30465      Widening of nasal passage                            3,286.00
# 15004      Preparation of graft site of face, scalp, eyeli...  20,261.00
# 20926      Tissue graft                                         4,608.00
# 21235      Obtaining ear cartilage for grafting                 5,216.00
# 31254      Partial removal of nasal sinus using an endoscope    4,835.00
# 31288      Removal of nasal sinus tissue using an endoscope     5,031.00
# 60240      Removal of thyroid                                   2,878.00
# 31571      Injection of vocal cords using an endoscope wit...   9,547.00
# 31541      Removal of growth of tongue and/or vocal cord s...   7,041.00
# 15120      Skin graft of face, scalp, eyelids, mouth, neck...   2,362.00
# 31253      Complete examination of nose and sinuses using ...   2,555.00
# 31536      Biopsy of voice box using an endoscope with ope...   5,727.00
# 30930      Therapeutic fracture of nasal passages               5,287.00
# 31259      Removal of tissue from sphenoid sinus using an ...   2,379.00
# 11642      Removal of malignant growth (1.1 to 2.0 centime...  14,749.00
# 42415      Partial removal of salivary gland growth with r...   1,624.00
# 60220      Total removal of thyroid lobe on one side of th...   1,772.00
# 69631      Repair of eardrum and ear canal with opening to...   1,204.00
# 30130      Removal of nasal air passage                         3,340.00
# 31257      Complete examination of nose and sinuses and re...   1,709.00
# 31535      Biopsy of voice box using an endoscope               4,688.00
# 31622      Diagnostic examination of lung airways using an...   9,250.00
# 15730      Creation of flap graft to midface                      824.00
# 11643      Removal of malignant growth (2.1 to 3.0 centime...   6,988.00
# 69801      Incision of fluid canals of inner ear with infu...   6,694.00
# 69433      Incision of eardrum with insertion of eardrum t...   5,358.00
# 38510      Biopsy or removal of lymph nodes of neck, open ...   1,566.00
# 30802      Destruction of soft tissue in nasal passages         3,056.00
# 43191      Diagnostic examination of esophagus using an en...   4,166.00
# 31238      Control of nasal bleeding using an endoscope         2,126.00
# 43200      Diagnostic examination of esophagus using an en...   5,260.00
# 31240      Removal of nasal breathing passages using an en...   1,440.00
# 31526      Diagnostic examination of voice box using an en...   2,110.00
# 42826      Removal of tonsils patient age 12 or over               12.00
#
# Category                                                                 \
# Stat
# Year                                                              Slope
# HCPCS Code HCPCS Description
# 14060      Tissue transfer repair of wound (10 sq centimet...   -334.80
# 69930      Implantation of cochlear device                       287.10
# 31267      Removal of nasal sinus tissue using an endoscope      596.30
# 30520      Reshaping of nasal cartilage                          366.10
# 30140      Removal of nasal air passage                        1,105.40
# 15260      Relocation of patient skin to nose, ears, eyeli...   -250.40
# 14301      Tissue transfer repair of wound (30.1 to 60.0 s...    204.00
# 14040      Tissue transfer repair of wound (10 sq centimet...   -421.00
# 31575      Diagnostic examination of voice box using flexi... -1,342.50
# 31276      Exploration of nasal sinus using an endoscope        -707.20
# 14041      Tissue transfer repair of wound (10.1 to 30.0 s...     -1.60
# 60500      Removal or exploration of parathyroid glands          177.00
# 31231      Diagnostic examination of nasal passages using ...  2,394.00
# 31579      Examination to assess movement of vocal cord fl...    916.30
# 69436      Incision of eardrum with insertion of eardrum t...    -79.20
# 31256      Incision of nasal sinus using an endoscope            -87.30
# 31525      Diagnostic examination of voice box using an en...  1,228.20
# 11042      Removal of skin and tissue first 20 sq cm or less     593.30
# 31237      Biopsy or removal of nasal polyp or tissue usin...    364.50
# 30465      Widening of nasal passage                              82.70
# 15004      Preparation of graft site of face, scalp, eyeli...    121.40
# 20926      Tissue graft                                           46.10
# 21235      Obtaining ear cartilage for grafting                  -11.00
# 31254      Partial removal of nasal sinus using an endoscope      50.10
# 31288      Removal of nasal sinus tissue using an endoscope     -342.70
# 60240      Removal of thyroid                                    -91.00
# 31571      Injection of vocal cords using an endoscope wit...    -19.50
# 31541      Removal of growth of tongue and/or vocal cord s...    -45.00
# 15120      Skin graft of face, scalp, eyelids, mouth, neck...     19.20
# 31253      Complete examination of nose and sinuses using ...    385.00
# 31536      Biopsy of voice box using an endoscope with ope...     -4.50
# 30930      Therapeutic fracture of nasal passages                 30.20
# 31259      Removal of tissue from sphenoid sinus using an ...    374.20
# 11642      Removal of malignant growth (1.1 to 2.0 centime...   -230.60
# 42415      Partial removal of salivary gland growth with r...    -15.00
# 60220      Total removal of thyroid lobe on one side of th...     22.90
# 69631      Repair of eardrum and ear canal with opening to...      7.20
# 30130      Removal of nasal air passage                          -45.60
# 31257      Complete examination of nose and sinuses and re...    266.80
# 31535      Biopsy of voice box using an endoscope                -28.00
# 31622      Diagnostic examination of lung airways using an...    -76.10
# 15730      Creation of flap graft to midface                     130.60
# 11643      Removal of malignant growth (2.1 to 3.0 centime...    -66.30
# 69801      Incision of fluid canals of inner ear with infu...   -110.60
# 69433      Incision of eardrum with insertion of eardrum t...    -10.20
# 38510      Biopsy or removal of lymph nodes of neck, open ...     -6.10
# 30802      Destruction of soft tissue in nasal passages           36.60
# 43191      Diagnostic examination of esophagus using an en...     13.40
# 31238      Control of nasal bleeding using an endoscope          -38.50
# 43200      Diagnostic examination of esophagus using an en...   -174.70
# 31240      Removal of nasal breathing passages using an en...     73.30
# 31526      Diagnostic examination of voice box using an en...    -30.20
# 42826      Removal of tonsils patient age 12 or over              -0.00
#
# Category                                                                     \
# Stat
# Year                                                              Intercept
# HCPCS Code HCPCS Description
# 14060      Tissue transfer repair of wound (10 sq centimet...    688,684.40
# 69930      Implantation of cochlear device                      -576,900.90
# 31267      Removal of nasal sinus tissue using an endoscope   -1,193,842.30
# 30520      Reshaping of nasal cartilage                         -728,375.70
# 30140      Removal of nasal air passage                       -2,217,309.20
# 15260      Relocation of patient skin to nose, ears, eyeli...    512,061.20
# 14301      Tissue transfer repair of wound (30.1 to 60.0 s...   -406,827.80
# 14040      Tissue transfer repair of wound (10 sq centimet...    856,496.80
# 31575      Diagnostic examination of voice box using flexi...  2,769,347.10
# 31276      Exploration of nasal sinus using an endoscope       1,431,661.60
# 14041      Tissue transfer repair of wound (10.1 to 30.0 s...      7,415.00
# 60500      Removal or exploration of parathyroid glands         -354,900.20
# 31231      Diagnostic examination of nasal passages using ... -4,792,858.60
# 31579      Examination to assess movement of vocal cord fl... -1,836,075.30
# 69436      Incision of eardrum with insertion of eardrum t...    163,832.00
# 31256      Incision of nasal sinus using an endoscope            179,705.90
# 31525      Diagnostic examination of voice box using an en... -2,470,751.40
# 11042      Removal of skin and tissue first 20 sq cm or less  -1,187,471.50
# 31237      Biopsy or removal of nasal polyp or tissue usin...   -730,600.50
# 30465      Widening of nasal passage                            -166,148.70
# 15004      Preparation of graft site of face, scalp, eyeli...   -240,811.60
# 20926      Tissue graft                                          -92,062.10
# 21235      Obtaining ear cartilage for grafting                   23,230.20
# 31254      Partial removal of nasal sinus using an endoscope    -100,084.70
# 31288      Removal of nasal sinus tissue using an endoscope      692,232.10
# 60240      Removal of thyroid                                    184,122.60
# 31571      Injection of vocal cords using an endoscope wit...     41,240.90
# 31541      Removal of growth of tongue and/or vocal cord s...     92,173.20
# 15120      Skin graft of face, scalp, eyelids, mouth, neck...    -38,254.00
# 31253      Complete examination of nose and sinuses using ...   -776,034.00
# 31536      Biopsy of voice box using an endoscope with ope...     10,221.90
# 30930      Therapeutic fracture of nasal passages                -59,856.00
# 31259      Removal of tissue from sphenoid sinus using an ...   -754,285.60
# 11642      Removal of malignant growth (1.1 to 2.0 centime...    468,070.00
# 42415      Partial removal of salivary gland growth with r...     30,579.80
# 60220      Total removal of thyroid lobe on one side of th...    -45,834.90
# 69631      Repair of eardrum and ear canal with opening to...    -14,281.60
# 30130      Removal of nasal air passage                           92,643.20
# 31257      Complete examination of nose and sinuses and re...   -537,793.80
# 31535      Biopsy of voice box using an endoscope                 57,413.60
# 31622      Diagnostic examination of lung airways using an...    155,343.70
# 15730      Creation of flap graft to midface                    -263,255.40
# 11643      Removal of malignant growth (2.1 to 3.0 centime...    135,124.70
# 69801      Incision of fluid canals of inner ear with infu...    224,419.00
# 69433      Incision of eardrum with insertion of eardrum t...     21,645.00
# 38510      Biopsy or removal of lymph nodes of neck, open ...     12,616.90
# 30802      Destruction of soft tissue in nasal passages          -73,211.00
# 43191      Diagnostic examination of esophagus using an en...    -26,194.60
# 31238      Control of nasal bleeding using an endoscope           78,079.70
# 43200      Diagnostic examination of esophagus using an en...    353,421.90
# 31240      Removal of nasal breathing passages using an en...   -147,558.10
# 31526      Diagnostic examination of voice box using an en...     61,335.40
# 42826      Removal of tonsils patient age 12 or over                   2.40
#
# Category
# Stat
# Year                                                              R    p
# HCPCS Code HCPCS Description
# 14060      Tissue transfer repair of wound (10 sq centimet... -0.93 0.02
# 69930      Implantation of cochlear device                     0.98 0.00
# 31267      Removal of nasal sinus tissue using an endoscope    0.98 0.00
# 30520      Reshaping of nasal cartilage                        0.93 0.02
# 30140      Removal of nasal air passage                        0.99 0.00
# 15260      Relocation of patient skin to nose, ears, eyeli... -0.89 0.05
# 14301      Tissue transfer repair of wound (30.1 to 60.0 s...  0.98 0.00
# 14040      Tissue transfer repair of wound (10 sq centimet... -0.91 0.03
# 31575      Diagnostic examination of voice box using flexi... -0.44 0.46
# 31276      Exploration of nasal sinus using an endoscope      -0.68 0.21
# 14041      Tissue transfer repair of wound (10.1 to 30.0 s... -0.01 0.99
# 60500      Removal or exploration of parathyroid glands        0.80 0.10
# 31231      Diagnostic examination of nasal passages using ...  0.87 0.06
# 31579      Examination to assess movement of vocal cord fl...  0.71 0.18
# 69436      Incision of eardrum with insertion of eardrum t... -0.69 0.19
# 31256      Incision of nasal sinus using an endoscope         -0.48 0.41
# 31525      Diagnostic examination of voice box using an en...  0.94 0.02
# 11042      Removal of skin and tissue first 20 sq cm or less   0.25 0.69
# 31237      Biopsy or removal of nasal polyp or tissue usin...  0.94 0.02
# 30465      Widening of nasal passage                           0.86 0.06
# 15004      Preparation of graft site of face, scalp, eyeli...  0.74 0.16
# 20926      Tissue graft                                        0.83 0.09
# 21235      Obtaining ear cartilage for grafting               -0.24 0.70
# 31254      Partial removal of nasal sinus using an endoscope   0.88 0.05
# 31288      Removal of nasal sinus tissue using an endoscope   -0.78 0.12
# 60240      Removal of thyroid                                 -0.81 0.10
# 31571      Injection of vocal cords using an endoscope wit... -0.20 0.75
# 31541      Removal of growth of tongue and/or vocal cord s... -0.52 0.37
# 15120      Skin graft of face, scalp, eyelids, mouth, neck...  0.57 0.32
# 31253      Complete examination of nose and sinuses using ...  0.87 0.06
# 31536      Biopsy of voice box using an endoscope with ope... -0.11 0.87
# 30930      Therapeutic fracture of nasal passages              0.71 0.18
# 31259      Removal of tissue from sphenoid sinus using an ...  0.89 0.04
# 11642      Removal of malignant growth (1.1 to 2.0 centime... -0.94 0.02
# 42415      Partial removal of salivary gland growth with r... -0.33 0.58
# 60220      Total removal of thyroid lobe on one side of th...  0.82 0.09
# 69631      Repair of eardrum and ear canal with opening to...  0.28 0.65
# 30130      Removal of nasal air passage                       -0.79 0.11
# 31257      Complete examination of nose and sinuses and re...  0.89 0.04
# 31535      Biopsy of voice box using an endoscope             -0.67 0.22
# 31622      Diagnostic examination of lung airways using an... -0.94 0.02
# 15730      Creation of flap graft to midface                   0.89 0.04
# 11643      Removal of malignant growth (2.1 to 3.0 centime... -0.84 0.07
# 69801      Incision of fluid canals of inner ear with infu... -0.85 0.07
# 69433      Incision of eardrum with insertion of eardrum t... -0.11 0.86
# 38510      Biopsy or removal of lymph nodes of neck, open ... -0.19 0.76
# 30802      Destruction of soft tissue in nasal passages        0.62 0.27
# 43191      Diagnostic examination of esophagus using an en...  0.34 0.58
# 31238      Control of nasal bleeding using an endoscope       -0.63 0.25
# 43200      Diagnostic examination of esophagus using an en... -1.00 0.00
# 31240      Removal of nasal breathing passages using an en...  0.96 0.01
# 31526      Diagnostic examination of voice box using an en... -0.64 0.25
# 42826      Removal of tonsils patient age 12 or over          -0.00 1.00
#
# [53 rows x 22 columns]

# %% [markdown]
# # County analysis

# %% [markdown]
# ## Load data

# %%
# @title Load spatial coordinates of counties
# Below is necessary for plotting chloropleths. 
with urllib.request.urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

# %%
# @title Load conversion df between FIPS code and county string
fips2county = pd.read_csv("data/fips2county.tsv", sep="\t", comment='#', dtype=str)

# %%
# @title Load our ENT df of all counties, their info, and the Moran's analysis
# The ent CSV file only contains the counties which are analyzable
df_counties_wide_orig = pd.read_csv("data/2022_04_10 ent initial output.csv", dtype={"FIPS": str})

# %%
# Merge with the fips 2 county standard data set
df_counties_wide = pd.merge(left=df_counties_wide_orig, right=fips2county, how="left", left_on='FIPS', right_on='CountyFIPS')
# Insert a county "County, ST" col (i.e. "Monmouth, NJ" or "Champaign, IL") for ease
df_counties_wide.insert(1, "County_St", df_counties_wide["CountyName"].astype(str) + ", " + df_counties_wide["StateAbbr"].astype(str))

# %%
info_simple = ["FIPS", "CountyName","StateAbbr", "% ASC Billing", "Moran I score for ACS billing fraction"]
info_main = ["FIPS", "County",	"StateFIPS", "Total Medicare Payment Amount", "% ASC Procedures", "% ASC Billing",	"CountyFIPS_3",	"CountyName",	"StateName",	"CountyFIPS",	"StateAbbr",	"STATE_COUNTY"]

df_counties_wide_simple=df_counties_wide[info_simple]
df_counties_wide_main=df_counties_wide[info_main]

# Display with all the columns
with pd.option_context('display.max_rows', 3, 'display.max_columns', None): 
    display(df_counties_wide_simple)
# Out:
#       FIPS    CountyName StateAbbr  % ASC Billing  \
# 0    01017      Chambers        AL       0.000000
# ..     ...           ...       ...            ...
# 940  51041  Chesterfield        VA      47.027037
#
#     Moran I score for ACS billing fraction
# 0                          Non Significant
# ..                                     ...
# 940                        Non Significant
#
# [941 rows x 5 columns]

# %% [markdown]
# ## Create long df from wide df- i.e. separate out the year columns into different rows

# %%
col_categories = ["Total Number of Services:", "Total Medicare Payment Amount:", "% ASC Procedures:", "% ASC Billing:"]
cols_to_keep = ["FIPS","County_St"]  # columns to keep in every subgroup so you can line up extra info later

# Create list of df's to combine later, each df is from melting of one category of columns
df_counties_longs = []

# Convert each type of category to long format in separate dataframes
for col_category in col_categories:
        df_counties_long = df_counties_wide.melt(id_vars=cols_to_keep, 
                               var_name="Year", 
                               value_vars=[f"{col_category} {year}" for year in range(2015, 2019 +1)], 
                               value_name=f"{col_category} in Year",
                               )
        df_counties_long["Year"] = df_counties_long["Year"].replace({ f"{col_category} {year}":f"{year}" for year in range(2015, 2019 +1)})
        df_counties_longs.append(df_counties_long)

# Merge the separate category dataframes
df_counties_long = df_counties_longs[0]
for ind in range(1,len(df_counties_longs)):
    df_counties_long = pd.merge(left=df_counties_long, right=df_counties_longs[ind], how="outer", on=(cols_to_keep+["Year"]) )

# Merge with the overall wide dataframe to keep those other values
df_counties_long = pd.merge(left=df_counties_long, 
                   right=df_counties_wide.drop([f"{col_category} {year}" for year in range(2015, 2019 +1) for col_category in col_categories], axis=1), 
                   how="left", on=cols_to_keep)

# %% [markdown]
# ## Create summary data by Moran category

# %%
categories = ["Total Number of Services","Total Medicare Payment Amount", "% ASC Procedures", "% ASC Billing" ]
# sorted_moran_values = df_counties_wide["Moran I score for ACS billing fraction"].unique()
sorted_moran_values = ["High-High","Low-Low","Low-High","High-Low","Non Significant"]  # list out specifically so you can get the order you want
sorted_moran_values_all = sorted_moran_values + ["All"]   #[pd.IndexSlice[:]]  # pd.IndexSlice[:]] represents all

value_counts = df_counties_wide["Moran I score for ACS billing fraction"].value_counts()[sorted_moran_values]

df_counties_with_slope = df_counties_wide.copy()
# Calculate regression and sum and mean from individual year later
for category in categories:
    new_df = df_counties_with_slope[ [category + ": " + str(yr) for yr in years] ].apply(calc_regression,axis=1, result_type="expand", args=(years,) )
    df_counties_with_slope[[category+": "+new_col for new_col in new_df.columns ]]=new_df
# To simplify, drop info for specific years unless it was "Mean" and "Slope" categories we just added
for category in categories:
    df_counties_with_slope = df_counties_with_slope.drop(columns=[col for col in df_counties_with_slope.columns if category in col and "Mean" not in col and "Slope" not in col])


df_counties_summary_dict = {}   # create a dict we will concatenate into a df later
# Options: 	[count, mean, std, min, 25%, 50%, 75%, max] assuming default percentiles argument
cols_to_show = ["10%","mean","90%"]
for possible_Moran_value in sorted_moran_values:
    df_counties_summary_dict[possible_Moran_value] = df_counties_with_slope[df_counties_with_slope["Moran I score for ACS billing fraction"]==possible_Moran_value].describe(percentiles=[.1,.25,.5,.75,.9]).loc[cols_to_show]
df_counties_summary_dict["All"] = df_counties_with_slope.describe(percentiles=[.1,.25,.5,.75,.9]).loc[cols_to_show]

df_counties_summary = pd.concat(df_counties_summary_dict.values(), axis=0, keys=df_counties_summary_dict.keys())
for possible_Moran_value in sorted_moran_values:
    df_counties_summary.loc[(possible_Moran_value,cols_to_show[0]), "N"] = value_counts[possible_Moran_value]

# Reorder into the sorted order we set above
df_counties_summary = df_counties_summary.loc[sorted_moran_values_all]

# %% [markdown]
# ## Create a more presentable format
# Select out only the columns you want and rename the columns

# %%
key_cols={
    'Total Number of Services: Mean': 'Number of Services: Annual' ,
    'Total Number of Services: Slope': 'Number of Services: Yearly Change' ,
    'Total Medicare Payment Amount: Mean' : "Medicare Payment: Annual",
    'Total Medicare Payment Amount: Slope' : "Medicare Payment: Yearly Change",
    '% ASC Billing: Mean': '% ASC Billing',
    '% ASC Billing: Slope': '% ASC Billing: Yearly Change',
    "% ASC Procedures: Mean": "% ASC Procedures",
    "% ASC Procedures: Slope": "% ASC Procedures: Yearly Change",
    "Average Age": "Average Age (years)",
    'Percent Male': "% Male",
    'Percent Non-Hispanic White': "% Non-Hispanic White",
    'Percent African American': "% African American",
    'Percent Hispanic': "% Hispanic",
    'Percent Eligible for Medicaid': "% Eligible for Medicaid",
    'pct_poverty': "% Poverty",
    'median_house_income': "Median Household Income",
    'unemployment': "Unemployment Rate",
    'pct_uninsured': "% Uninsured",
    'tabacco': "% Tobacco Use",
    'obesity': "% Obesity",
    #"Asthma": "% with Asthma",
    '2013_Rural_urban_cont_code': "RUCA",
    'pop': "Overall Population",
    'Beneficiaries with Part A and Part B': "Medicare Beneficiaries Population",
    'Population Density': "Overall Population Density",
    'Medicare Population Density': "Medicare Population Density",
}
df_counties_long["Year"].replace({ f"{col_category} {year}":f"{year}" for year in range(2015, 2019 +1)})
df_counties_summary_clean = df_counties_summary[key_cols.keys()]
df_counties_summary_clean = df_counties_summary_clean.rename(columns=key_cols).transpose()

with pd.option_context('display.float_format', '{:,.2f}'.format):
    display( df_counties_summary_clean )

save_df(df_counties_summary_clean, "df_counties_summary_clean")
# Out:
#                                    High-High                          Low-Low  \
#                                          10%       mean        90%        10%
# Number of Services: Annual             54.38   1,159.12   1,185.06       8.72
# Number of Services: Yearly Change    -115.49      66.53      54.78    -193.22
# Medicare Payment: Annual           16,018.24 218,757.69 439,851.70     798.98
# Medicare Payment: Yearly Change   -22,898.25  11,281.08  26,467.42 -11,950.69
# % ASC Billing                          37.72      69.28      90.97       0.00
# % ASC Billing: Yearly Change           -4.89       1.44       8.11       0.00
# % ASC Procedures                       17.44      51.27      80.33       0.00
# % ASC Procedures: Yearly Change        -6.74       1.34       9.26       0.00
# Average Age (years)                    71.00      72.41      74.00      68.80
# % Male                                 42.93      44.69      46.80      44.12
# % Non-Hispanic White                   63.48      80.69      92.80      77.03
# % African American                      1.32       8.87      19.75       0.31
# % Hispanic                              0.93       5.83      14.06       0.29
# % Eligible for Medicaid                 9.93      16.61      23.62      15.45
# % Poverty                               6.90      12.54      19.14       8.42
# Median Household Income            47,690.34  64,248.34  90,205.08  42,085.80
# Unemployment Rate                       3.60       4.76       5.97       2.88
# % Uninsured                             5.90      10.75      16.56       4.64
# % Tobacco Use                           5.00       7.65      10.04       8.20
# % Obesity                              13.00      19.13      25.12      13.08
# RUCA                                    1.00       1.92       3.00       1.00
# Overall Population                102,551.02 547,666.81 914,269.40  36,255.12
# Medicare Beneficiaries Population  15,823.74  91,698.25 143,264.70   8,175.44
# Overall Population Density            129.82     786.57   1,906.68      48.11
# Medicare Population Density            20.49     134.04     265.73      10.74
#
#                                                          Low-High             \
#                                         mean        90%       10%       mean
# Number of Services: Annual            509.23   1,402.84      3.18   1,329.63
# Number of Services: Yearly Change     -36.53      96.40    -97.49       5.62
# Medicare Payment: Annual           32,316.77  82,467.87    535.71 110,704.38
# Medicare Payment: Yearly Change    -1,522.32   5,963.24 -6,221.68     658.62
# % ASC Billing                           1.12       1.83      0.00       2.74
# % ASC Billing: Yearly Change            0.03       0.00     -1.16      -0.51
# % ASC Procedures                        0.45       0.37      0.00       0.93
# % ASC Procedures: Yearly Change        -0.05       0.00     -0.13      -0.22
# Average Age (years)                    70.37      72.00     69.66      71.49
# % Male                                 45.95      47.51     42.75      45.13
# % Non-Hispanic White                   88.03      96.23     53.49      77.02
# % African American                      4.13      10.02      0.65      12.98
# % Hispanic                              1.22       2.31      0.57       5.69
# % Eligible for Medicaid                23.85      33.66     10.35      19.00
# % Poverty                              13.96      20.09      8.28      14.25
# Median Household Income            54,240.51  68,665.08 41,664.62  59,892.96
# Unemployment Rate                       4.58       6.32      3.23       4.67
# % Uninsured                             7.27      11.10      6.70      11.58
# % Tobacco Use                          11.62      16.52      5.66       8.58
# % Obesity                              18.90      25.68     10.78      17.94
# RUCA                                    3.48       6.20      1.00       2.45
# Overall Population                139,314.42 295,239.28 38,369.24 364,308.18
# Medicare Beneficiaries Population  26,068.30  53,127.36  7,982.90  54,116.59
# Overall Population Density            329.06     564.37     57.40   3,578.97
# Medicare Population Density            59.85     104.50     12.60     484.37
#
#                                                High-Low                        \
#                                          90%        10%       mean        90%
# Number of Services: Annual          3,205.98      29.88     449.44     933.24
# Number of Services: Yearly Change     111.17     -99.64      -8.57      44.26
# Medicare Payment: Annual          231,874.86   4,393.20  89,373.96 182,863.41
# Medicare Payment: Yearly Change    11,706.62 -10,510.83  -1,728.66  13,796.86
# % ASC Billing                          12.17      20.00      54.10      90.51
# % ASC Billing: Yearly Change            0.00      -8.73       3.73      19.47
# % ASC Procedures                        3.25      11.64      39.08      79.02
# % ASC Procedures: Yearly Change         0.06      -6.97       3.04      17.66
# Average Age (years)                    73.00      69.72      71.09      72.20
# % Male                                 47.38      43.67      44.96      46.91
# % Non-Hispanic White                   94.02      76.93      88.98      95.52
# % African American                     31.70       0.54       6.47      17.69
# % Hispanic                             12.93       0.51       1.41       2.13
# % Eligible for Medicaid                30.03      12.22      19.47      27.38
# % Poverty                              23.39       4.90      12.41      18.76
# Median Household Income            81,987.56  44,606.88  61,317.02  87,788.60
# Unemployment Rate                       6.14       3.07       4.19       5.58
# % Uninsured                            16.87       3.92       7.11      10.57
# % Tobacco Use                          11.74       7.52       9.96      13.60
# % Obesity                              22.80      13.00      18.50      25.44
# RUCA                                    4.70       1.00       2.33       4.00
# Overall Population                816,765.32  53,049.72 266,809.62 601,163.60
# Medicare Beneficiaries Population 112,862.70  10,876.36  46,366.38 100,964.32
# Overall Population Density          8,732.64      88.30     596.57   1,666.76
# Medicare Population Density         1,068.83      16.03     105.15     299.16
#
#                                   Non Significant                        \
#                                               10%       mean        90%
# Number of Services: Annual                   8.20     714.79   1,419.24
# Number of Services: Yearly Change         -101.06      -7.06      77.28
# Medicare Payment: Annual                 1,066.88  98,025.92 212,296.85
# Medicare Payment: Yearly Change         -9,348.72   2,862.39  16,823.63
# % ASC Billing                                0.00      22.85      76.19
# % ASC Billing: Yearly Change                -2.69       0.57       6.97
# % ASC Procedures                             0.00      16.67      56.60
# % ASC Procedures: Yearly Change             -2.79       0.36       5.12
# Average Age (years)                         69.60      71.19      73.00
# % Male                                      43.41      45.26      47.39
# % Non-Hispanic White                        59.72      80.42      95.37
# % African American                           0.35       8.54      24.40
# % Hispanic                                   0.43       4.09       9.26
# % Eligible for Medicaid                     11.24      19.84      29.10
# % Poverty                                    8.13      14.51      21.17
# Median Household Income                 42,061.28  56,602.97  77,497.60
# Unemployment Rate                            3.14       4.50       5.88
# % Uninsured                                  5.68      10.80      16.38
# % Tobacco Use                                6.20       9.80      13.40
# % Obesity                                   12.00      17.48      23.80
# RUCA                                         1.00       2.96       6.00
# Overall Population                      35,394.92 270,818.28 693,455.68
# Medicare Beneficiaries Population        7,176.48  41,895.50  95,213.12
# Overall Population Density                  41.71     491.91   1,177.16
# Medicare Population Density                  8.54      76.80     183.13
#
#                                          All
#                                          10%       mean        90%
# Number of Services: Annual              8.40     765.97   1,616.80
# Number of Services: Yearly Change    -124.40      -3.43      76.70
# Medicare Payment: Annual            1,108.60 100,560.44 219,473.75
# Medicare Payment: Yearly Change   -11,701.57   2,685.58  15,954.26
# % ASC Billing                           0.00      23.60      79.88
# % ASC Billing: Yearly Change           -2.75       0.60       5.87
# % ASC Procedures                        0.00      17.13      60.49
# % ASC Procedures: Yearly Change        -2.68       0.44       5.04
# Average Age (years)                    69.40      71.21      73.00
# % Male                                 43.40      45.29      47.35
# % Non-Hispanic White                   61.45      81.60      95.62
# % African American                      0.36       8.20      22.26
# % Hispanic                              0.42       3.87       8.37
# % Eligible for Medicaid                11.07      20.05      29.79
# % Poverty                               7.90      14.15      20.96
# Median Household Income            42,571.60  57,409.27  77,843.60
# Unemployment Rate                       3.12       4.54       5.96
# % Uninsured                             5.44      10.20      16.18
# % Tobacco Use                           6.20       9.78      13.60
# % Obesity                              12.00      17.92      24.20
# RUCA                                    1.00       2.88       6.00
# Overall Population                 37,167.20 285,083.21 687,488.20
# Medicare Beneficiaries Population   7,537.80  45,438.71 102,724.80
# Overall Population Density             46.65     742.47   1,394.10
# Medicare Population Density             9.35     112.82     222.39
